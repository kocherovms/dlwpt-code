# %%
import torch
from torch import hub

# %%
resnet_model = hub.load('pytorch/vision:main', 'resnet50', pretrained=True)
# Out:
# Using cache found in /home/misha/.cache/torch/hub/pytorch_vision_main
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 resnet_model = hub.load('pytorch/vision:main', 'resnet50', pretrained=True)
#
# File ~/anaconda3/envs/mine/lib/python3.12/site-packages/torch/hub.py:652, in load(repo_or_dir, model, source, trust_repo, force_reload, verbose, skip_validation, *args, **kwargs)
#     642 if source == "github":
#     643     repo_or_dir = _get_cache_or_reload(
#     644         repo_or_dir,
#     645         force_reload,
#    (...)
#     649         skip_validation=skip_validation,
#     650     )
# --> 652 model = _load_local(repo_or_dir, model, *args, **kwargs)
#     653 return model
#
# File ~/anaconda3/envs/mine/lib/python3.12/site-packages/torch/hub.py:682, in _load_local(hubconf_dir, model, *args, **kwargs)
# ...
